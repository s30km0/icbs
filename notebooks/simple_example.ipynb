# %% [markdown]
# Copyright Amazon.com, Inc. or its affiliates. All Rights Reserved. <br>
# SPDX-License-Identifier: CC-BY-NC-4.0

# %% [markdown]
# # Simple Example
#
# This example shows how to prune a simple feed forward network that we trained on the Fashion-MNIST dataset. We refer to this model as the "Garment Classifier". If your model is an LLM, please see `simple_example_llm.ipynb` instead.

# %% [markdown]
# ### Imports

# %%
import sys
import os

# 프로젝트 루트 디렉토리의 절대 경로를 얻습니다
project_root = os.path.abspath(os.path.join(os.getcwd(), '../notebooks'))
# 또는 직접 경로를 지정할 수도 있습니다
# project_root = "/path/to/your/project"

# src 디렉토리를 Python 경로에 추가
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
import multiprocessing

import os
import pickle
import time
from collections import defaultdict
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import DataLoader

from garment_classifier import load_fashion_mnist, load_garment_classifier
from icbs.evaluation import evaluate_model
from icbs.loops import prune_loop
from icbs.pruner import Pruner
from icbs.solvers import ConstrainedSASolver
from icbs.util import calc_density, get_log_w_names_step, get_named_weights
from util import load_dataset, set_num_threads, set_seed

# %% [markdown]
# ### Settings
#
# Some settings are chosen specifically so that this notebook can be run in a short time.  In such cases, the settings used for this model in the paper are included after the # symbol.

# %%
# Model and dataset
model_name = "garment_classifier"
dataset_name = "zalando-datasets/fashion_mnist"
dataset_args = {}
device = "cuda" if torch.cuda.is_available() else "cpu"

# Pruner parameters
seed = 43
density = 0.1
pruner_num_epochs = 10
num_steps_per_epoch = 3  # 300
init_method = "magnitude"
block_size = 1024
num_restarts = 10
min_num_steps_per_layer = 1
selection_method = "gradient"
calc_hessian_method = "gradient_per_sample"
grad_multiplier = 0.75
ridge_multiplier = 0.001
verbose = 2

# Batch sizes
batch_size_evaluation = 4096
batch_size_pruning = 200
batch_size_calibration = 4096
max_batch_size = None  # Small dataset - don't need accumulation

# Block settings
block_solver = ConstrainedSASolver(verbose=verbose, num_restarts=num_restarts)
k = block_size // 2
tabu_frac = 0.40
fix_frac_prune = 0.42
fix_frac_keep = 0.35

# Workers, etc.
num_cpus = multiprocessing.cpu_count()
dataloader_args = {
    "num_workers": 4 if torch.cuda.is_available() else 0,
    "pin_memory": False,
}

# Only prune linear layers and do not prune the final layer
keep_layers = (torch.nn.Linear,)
layer_name_to_exclude = None

# The loss function
loss_function = nn.CrossEntropyLoss()

# Set the number of threads and seed the random number generator
set_num_threads(num_cpus)
set_seed(seed)

# %% [markdown]
# ## Load a model
#
# When running on a machine with multiple GPUs, the print out below this cell will show the distribution of the model across GPUs.

# %%
# Load a fresh model
# Note: it's important to load the model before getting a reference
# to the weights (below)
model = load_garment_classifier(device)

# %% [markdown]
# Choose which layer to prune at each step.

# %%
# The list of layers to process
named_weights = get_named_weights(model, keep_layers)
named_weights = {
    name: weights
    for name, weights in named_weights.items()
    if layer_name_to_exclude is None or layer_name_to_exclude not in name
}
layer_names = list(named_weights.keys())
print(f"Pruning {len(layer_names)} layers")

# The distribution of steps to weights
w_names_step = get_log_w_names_step(
    named_weights, num_steps_per_epoch, min_num_steps_per_layer
)
# Out:
# Pruning 3 layers

# %% [markdown]
# ## Load a dataset

# %% [markdown]
# First we load the dataset:

# %%
train_dataset, valid_dataset = load_fashion_mnist()
# Out:
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to data/FashionMNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 26421880/26421880 [00:06<00:00, 4403046.90it/s]
# Extracting data/FashionMNIST/raw/train-images-idx3-ubyte.gz to data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to data/FashionMNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 29515/29515 [00:00<00:00, 100358.47it/s]
# Extracting data/FashionMNIST/raw/train-labels-idx1-ubyte.gz to data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 4422102/4422102 [00:02<00:00, 1844105.27it/s]
# Extracting data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 5148/5148 [00:00<00:00, 3966252.20it/s]
# Extracting data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to data/FashionMNIST/raw

# %% [markdown]
# Then we set up data loaders for pruning and validation:

# %%
# Pruning dataloader
prune_dataloader = DataLoader(
    train_dataset,
    batch_size=batch_size_pruning,
    shuffle=False,
    **dataloader_args,
)

# Data loader
valid_dataloader = DataLoader(
    valid_dataset,
    batch_size=batch_size_evaluation,
    shuffle=False,
    **dataloader_args,
)

# %% [markdown]
# If the initial selection of weights to prune is done using Wanda or the Gradient option, then we also need to provide the calibaration data:

# %%
if init_method.startswith("wanda") or init_method.startswith("gradient"):
    calibration_dataloader = DataLoader(
        train_dataset,
        batch_size=batch_size_calibration,
        shuffle=False,  # Set to True for any dataset that is not streamed
        **dataloader_args,
    )
    X_init, y_init = next(iter(calibration_dataloader))

else:
    X_init, y_init = None, None

# %% [markdown]
# ## Evaluate the model (before pruning)
#
# We check the performance of the model before pruning, as a point of reference:

# %%
print("Evaluating model before pruning:")
unpruned_evaluation_start_time = time.time()
unpruned_valid_accuracy, unpruned_valid_loss, unpruned_evaluation_time = evaluate_model(
    valid_dataloader, model, loss_function, device
)
unpruned_evaluation_time = time.time() - unpruned_evaluation_start_time
print(f"Initial evaluation took: {unpruned_evaluation_time/60:.2f}min")
# Out:
# Evaluating model before pruning:
#   Accuracy: 86.19%, Loss: 0.381503
#   Evaluation time: evaluation_time=0.5sec
# Initial evaluation took: 0.01min

# %% [markdown]
# ## Run

# %% [markdown]
# For demonstration purposes, the below will even run on a CPU and should take a few minutes (depending on the specs). However, we recommend running any actual experiments on a machine with at least one GPU. First we instantiate the pruner, which will already perform the initial pruning:

# %%
initial_pruning_start_time = time.time()

print("*" * 80)
print(
    f"Pruning weights across all layers using {density=} "
    f"block_solver={block_solver.__class__.__name__} "
    f"{block_size=} {k=} {init_method=} {selection_method=} "
    f"{grad_multiplier=} {ridge_multiplier=} {calc_hessian_method=} "
    f"{seed=} {tabu_frac=} {fix_frac_prune=} {fix_frac_keep=} \n"
)

pruner = Pruner(
    model,
    loss_function,
    density,
    block_solver,
    block_size,
    k,
    layer_names,
    init_method,
    selection_method,
    grad_multiplier,
    ridge_multiplier,
    calc_hessian_method,
    seed,
    verbose,
    X_init=X_init,
    y_init=y_init,
    tabu_frac=tabu_frac,
    fix_frac_prune=fix_frac_prune,
    fix_frac_keep=fix_frac_keep,
    max_batch_size=max_batch_size,
)

print(f"Target density: {density} Actual density: {calc_density(model):.4f}")

print("Evaluating model after initial pruning:")
valid_accuracy, valid_loss, evaluation_time = evaluate_model(
    valid_dataloader, model, loss_function, device
)

initial_pruning_time = time.time() - initial_pruning_start_time
print(f"Initial pruning and validation took: {initial_pruning_time/60:.2f}min")
# Out:
# ********************************************************************************
# Pruning weights across all layers using density=0.1 block_solver=ConstrainedSASolver block_size=1024 k=512 init_method='magnitude' selection_method='gradient' grad_multiplier=0.75 ridge_multiplier=0.001 calc_hessian_method='gradient_per_sample' seed=43 tabu_frac=0.4 fix_frac_prune=0.42 fix_frac_keep=0.35
#
# Resetting pruner
# Performing initial pruning on layer linear_relu_stack.linear1.weight
# w_name='linear_relu_stack.linear1.weight', num_weights=401408, self.density=0.1, num_fix_keep=14049, num_fix_prune=151732
# Done with initial pruning of layer linear_relu_stack.linear1.weight, layer_density=0.100
#     _perform_init_pruning_layer() took: 0.16s
# Performing initial pruning on layer linear_relu_stack.linear2.weight
# w_name='linear_relu_stack.linear2.weight', num_weights=262144, self.density=0.1, num_fix_keep=9175, num_fix_prune=99091
# Done with initial pruning of layer linear_relu_stack.linear2.weight, layer_density=0.100
#     _perform_init_pruning_layer() took: 0.10s
# Performing initial pruning on layer linear_relu_stack.linear3.weight
# w_name='linear_relu_stack.linear3.weight', num_weights=5120, self.density=0.1, num_fix_keep=179, num_fix_prune=1935
# Done with initial pruning of layer linear_relu_stack.linear3.weight, layer_density=0.100
#     _perform_init_pruning_layer() took: 0.00s
# Done with initial pruning in 0.26s
# Target density: 0.1 Actual density: 0.1000
# Evaluating model after initial pruning:
#   Accuracy: 60.73%, Loss: 1.339443
#   Evaluation time: evaluation_time=0.5sec
# Initial pruning and validation took: 0.01min

# %% [markdown]
# Then we run the optimization-based pruning steps to (hopefully) improve on the initial pruning:

# %%
experiment_start_time = time.time()

valid_losses = [valid_loss]
valid_accuracies = [valid_accuracy]
prune_times = [0.0]
evaluation_times = [evaluation_time]
for num_epoch in range(1, pruner_num_epochs + 1):
    print("-" * 80)
    print(f"{num_epoch=}")
    start_time = time.time()
    w_names_step = np.random.permutation(w_names_step)
    prune_loop(
        prune_dataloader,
        model,
        pruner,
        device,
        w_names_step,
        verbose=1 if verbose else None,
    )
    prune_time = time.time() - start_time

    print(f"\nEvaluating model after epoch {num_epoch}:")
    valid_accuracy, valid_loss, evaluation_time = evaluate_model(
        valid_dataloader, model, loss_function, device
    )
    print(f"  Time: {prune_time=:.1f}sec\n")

    valid_losses.append(valid_loss)
    valid_accuracies.append(valid_accuracy)
    prune_times.append(prune_time)
    evaluation_times.append(evaluation_time)

experiment_time = time.time() - experiment_start_time
print(f"Experiment took: {experiment_time/60:.2f}min")
# Out:
# --------------------------------------------------------------------------------
# num_epoch=1
# -----------------------
# Pruner step 1 (of 3)
#     Calculated gradient in 0.02s
#     w_name='linear_relu_stack.linear2.weight' k_effective=512
#     _calc_grad_sample_block() took: 0.04s
#     _calc_hess_block() took: 0.04s
#     scaling=5.580e+05 cutoff=1.000e-12 Q_density=0.25048 Q_density_cutoff=0.13147
#     Solving with ConstrainedSASolver, problem_filename=PosixPath('.25435_250619_150905119755_cb93494bfcb34226850d903b8249ea03.tmp')
#     n=1024 best_E=520.142 elapsed_time=3.836
#     dL=-0.076 dE=-0.075 ridge_contribution=0.002 const=-0.076 best_E=0.001 dL_eval=-0.061 delta_w_squared=1.537
#     Pruner step took: 5.11s
# -----------------------
# Pruner step 2 (of 3)
#     Calculated gradient in 0.00s
#     w_name='linear_relu_stack.linear3.weight' k_effective=512
#     _calc_grad_sample_block() took: 0.00s
#     _calc_hess_block() took: 0.00s
#     scaling=7.399e+04 cutoff=1.000e-12 Q_density=0.99969 Q_density_cutoff=0.54300
#     Solving with ConstrainedSASolver, problem_filename=PosixPath('.25435_250619_150910154157_619e80dd28b14f2bb64b0de6b3df5af5.tmp')
#     n=845 best_E=49316.492 elapsed_time=1.224
#     dL=0.408 dE=0.411 ridge_contribution=0.004 const=-0.255 best_E=0.667 dL_eval=-0.018 delta_w_squared=3.525
#     Pruner step took: 2.01s
# -----------------------
# Pruner step 3 (of 3)
#     Calculated gradient in 0.02s
#     w_name='linear_relu_stack.linear1.weight' k_effective=512
#     _calc_grad_sample_block() took: 0.05s
#     _calc_hess_block() took: 0.06s
#     scaling=8.881e+06 cutoff=1.000e-12 Q_density=0.84108 Q_density_cutoff=0.42403
#     Solving with ConstrainedSASolver, problem_filename=PosixPath('.25435_250619_150912304508_76bef9d99c5340eeb607e0ceca714cd7.tmp')
#     n=1024 best_E=8320.382 elapsed_time=2.471
#     dL=-0.017 dE=-0.016 ridge_contribution=0.001 const=-0.017 best_E=0.001 dL_eval=-0.028 delta_w_squared=0.957
#     Pruner step took: 3.60s
#
# Evaluating model after epoch 1:
#   Accuracy: 73.59%, Loss: 1.206399
#   Evaluation time: evaluation_time=0.5sec
#   Time: prune_time=10.8sec
#
# --------------------------------------------------------------------------------
# num_epoch=2
# -----------------------
# Pruner step 1 (of 3)
#     Calculated gradient in 0.02s
#     w_name='linear_relu_stack.linear1.weight' k_effective=512
#     _calc_grad_sample_block() took: 0.06s
#     _calc_hess_block() took: 0.06s
#     scaling=1.152e+07 cutoff=1.000e-12 Q_density=0.99353 Q_density_cutoff=0.50184
#     Solving with ConstrainedSASolver, problem_filename=PosixPath('.25435_250619_150916430865_c6e5c7d2087c47ed8e238843cc676c26.tmp')
#     n=1024 best_E=13546.243 elapsed_time=2.524
#     dL=-0.017 dE=-0.016 ridge_contribution=0.001 const=-0.017 best_E=0.001 dL_eval=-0.027 delta_w_squared=0.935
#     Pruner step took: 3.74s
# -----------------------
# Pruner step 2 (of 3)
#     Calculated gradient in 0.00s
#     w_name='linear_relu_stack.linear3.weight' k_effective=512
#     _calc_grad_sample_block() took: 0.00s
#     _calc_hess_block() took: 0.00s
#     scaling=1.348e+05 cutoff=1.000e-12 Q_density=0.99984 Q_density_cutoff=0.55959
#     Solving with ConstrainedSASolver, problem_filename=PosixPath('.25435_250619_150920037979_17022e845d0d4badafd63f6f80bd650e.tmp')
#     n=512 best_E=124131.383 elapsed_time=0.000
# WARNING: move does not change the weights, i.e., delta_w=0
#     Pruner step took: 0.33s
# -----------------------
# Pruner step 3 (of 3)
#     Calculated gradient in 0.02s
#     w_name='linear_relu_stack.linear2.weight' k_effective=512
#     _calc_grad_sample_block() took: 0.04s
#     _calc_hess_block() took: 0.04s
#     scaling=1.324e+06 cutoff=1.000e-12 Q_density=0.25049 Q_density_cutoff=0.13013
#     Solving with ConstrainedSASolver, problem_filename=PosixPath('.25435_250619_150920473970_26cc58dc93c04a5e9306f74a5bac26c1.tmp')
#     n=1024 best_E=1237.175 elapsed_time=3.762
#     dL=-0.056 dE=-0.055 ridge_contribution=0.002 const=-0.056 best_E=0.001 dL_eval=-0.048 delta_w_squared=1.521
#     Pruner step took: 4.58s
#
# Evaluating model after epoch 2:
#   Accuracy: 77.92%, Loss: 1.125246
#   Evaluation time: evaluation_time=0.5sec
#   Time: prune_time=8.7sec
#
# --------------------------------------------------------------------------------
# num_epoch=3
# -----------------------
# Pruner step 1 (of 3)
#     Calculated gradient in 0.02s
#     w_name='linear_relu_stack.linear1.weight' k_effective=512
#     _calc_grad_sample_block() took: 0.05s
#     _calc_hess_block() took: 0.05s
#     scaling=1.387e+07 cutoff=1.000e-12 Q_density=0.99836 Q_density_cutoff=0.50688
#     Solving with ConstrainedSASolver, problem_filename=PosixPath('.25435_250619_150925617176_97b28f795a4248c6a4c206930cbd5210.tmp')
#     n=1024 best_E=17939.582 elapsed_time=2.408
#     dL=-0.014 dE=-0.013 ridge_contribution=0.001 const=-0.014 best_E=0.001 dL_eval=-0.025 delta_w_squared=0.881
#     Pruner step took: 3.63s
# -----------------------
# Pruner step 2 (of 3)
#     Calculated gradient in 0.01s
#     w_name='linear_relu_stack.linear2.weight' k_effective=512
#     _calc_grad_sample_block() took: 0.04s
#     _calc_hess_block() took: 0.04s
#     scaling=1.616e+06 cutoff=1.000e-12 Q_density=0.25041 Q_density_cutoff=0.13265
#     Solving with ConstrainedSASolver, problem_filename=PosixPath('.25435_250619_150929200912_406cd2a632a74c8cb988b39b13c40a87.tmp')
#     n=1024 best_E=1507.765 elapsed_time=3.766
#     dL=-0.044 dE=-0.043 ridge_contribution=0.002 const=-0.044 best_E=0.001 dL_eval=-0.038 delta_w_squared=1.520
#     Pruner step took: 4.52s
# -----------------------
# Pruner step 3 (of 3)
#     Calculated gradient in 0.00s
#     w_name='linear_relu_stack.linear3.weight' k_effective=512
#     _calc_grad_sample_block() took: 0.00s
#     _calc_hess_block() took: 0.00s
#     scaling=1.875e+05 cutoff=1.000e-12 Q_density=0.99986 Q_density_cutoff=0.54528
#     Solving with ConstrainedSASolver, problem_filename=PosixPath('.25435_250619_150933641759_93fc879052cb4697a44e1e42a64ff1a0.tmp')
#     n=614 best_E=64480.103 elapsed_time=0.363
#     dL=0.261 dE=0.261 ridge_contribution=0.000 const=-0.083 best_E=0.344 dL_eval=-0.015 delta_w_squared=0.360
#     Pruner step took: 0.81s
#
# Evaluating model after epoch 3:
#   Accuracy: 80.04%, Loss: 1.062049
#   Evaluation time: evaluation_time=0.6sec
#   Time: prune_time=9.0sec
#
# --------------------------------------------------------------------------------
# num_epoch=4
# -----------------------
# Pruner step 1 (of 3)
#     Calculated gradient in 0.00s
#     w_name='linear_relu_stack.linear3.weight' k_effective=512
#     _calc_grad_sample_block() took: 0.00s
#     _calc_hess_block() took: 0.00s
#     scaling=1.517e+05 cutoff=1.000e-12 Q_density=0.99994 Q_density_cutoff=0.53917
#     Solving with ConstrainedSASolver, problem_filename=PosixPath('.25435_250619_150935074056_21bb88dbab514f7b8719bc1b2abf4549.tmp')
#     n=684 best_E=59116.486 elapsed_time=0.602
#     dL=0.227 dE=0.228 ridge_contribution=0.001 const=-0.162 best_E=0.390 dL_eval=-0.025 delta_w_squared=0.686
#     Pruner step took: 1.13s
# -----------------------
# Pruner step 2 (of 3)
#     Calculated gradient in 0.02s
#     w_name='linear_relu_stack.linear1.weight' k_effective=512
#     _calc_grad_sample_block() took: 0.05s
#     _calc_hess_block() took: 0.05s
#     scaling=1.190e+07 cutoff=1.000e-12 Q_density=0.98495 Q_density_cutoff=0.49508
#     Solving with ConstrainedSASolver, problem_filename=PosixPath('.25435_250619_150936355640_e943f87540ce4eeb85fb8cf5c908f249.tmp')
#     n=1024 best_E=16867.951 elapsed_time=2.279
#     dL=0.000 dE=0.001 ridge_contribution=0.001 const=-0.000 best_E=0.001 dL_eval=-0.021 delta_w_squared=0.954
#     Pruner step took: 3.49s
# -----------------------
# Pruner step 3 (of 3)
#     Calculated gradient in 0.02s
#     w_name='linear_relu_stack.linear2.weight' k_effective=512
#     _calc_grad_sample_block() took: 0.04s
#     _calc_hess_block() took: 0.04s
#     scaling=2.231e+06 cutoff=1.000e-12 Q_density=0.25049 Q_density_cutoff=0.12891
#     Solving with ConstrainedSASolver, problem_filename=PosixPath('.25435_250619_150939803108_adb9ba6b802345d98356695b6283ca9d.tmp')
#     n=1024 best_E=2064.135 elapsed_time=3.795
#     dL=-0.012 dE=-0.010 ridge_contribution=0.001 const=-0.011 best_E=0.001 dL_eval=-0.026 delta_w_squared=1.454
#     Pruner step took: 4.54s
#
# Evaluating model after epoch 4:
#   Accuracy: 80.80%, Loss: 0.998331
#   Evaluation time: evaluation_time=0.5sec
#   Time: prune_time=9.2sec
#
# --------------------------------------------------------------------------------
# num_epoch=5
# -----------------------
# Pruner step 1 (of 3)
#     Calculated gradient in 0.02s
#     w_name='linear_relu_stack.linear1.weight' k_effective=512
#     _calc_grad_sample_block() took: 0.05s
#     _calc_hess_block() took: 0.06s
#     scaling=1.482e+07 cutoff=1.000e-12 Q_density=0.95243 Q_density_cutoff=0.47846
#     Solving with ConstrainedSASolver, problem_filename=PosixPath('.25435_250619_150944919360_97bcea0da5ba47e4acde60150329a9a4.tmp')
#     n=1024 best_E=15602.200 elapsed_time=2.497
#     dL=-0.008 dE=-0.007 ridge_contribution=0.001 const=-0.008 best_E=0.001 dL_eval=-0.018 delta_w_squared=0.889
#     Pruner step took: 3.69s
# -----------------------
# Pruner step 2 (of 3)
#     Calculated gradient in 0.02s
#     w_name='linear_relu_stack.linear2.weight' k_effective=512
#     _calc_grad_sample_block() took: 0.04s
#     _calc_hess_block() took: 0.04s
#     scaling=1.913e+06 cutoff=1.000e-12 Q_density=0.25049 Q_density_cutoff=0.13019
#     Solving with ConstrainedSASolver, problem_filename=PosixPath('.25435_250619_150948566556_e3f1e45624114ae8a0f12ff6b7877796.tmp')
#     n=1024 best_E=1785.571 elapsed_time=3.492
#     dL=-0.002 dE=-0.001 ridge_contribution=0.001 const=-0.002 best_E=0.001 dL_eval=-0.025 delta_w_squared=1.475
#     Pruner step took: 4.24s
# -----------------------
# Pruner step 3 (of 3)
#     Calculated gradient in 0.00s
#     w_name='linear_relu_stack.linear3.weight' k_effective=512
#     _calc_grad_sample_block() took: 0.00s
#     _calc_hess_block() took: 0.00s
#     scaling=1.188e+05 cutoff=1.000e-12 Q_density=0.99980 Q_density_cutoff=0.53340
#     Solving with ConstrainedSASolver, problem_filename=PosixPath('.25435_250619_150952728903_132379b2848342e6b1cbacdf1a8498fc.tmp')
#     n=597 best_E=75041.786 elapsed_time=0.337
#     dL=0.531 dE=0.532 ridge_contribution=0.001 const=-0.099 best_E=0.631 dL_eval=0.015 delta_w_squared=0.585
#     Pruner step took: 0.75s
#
# Evaluating model after epoch 5:
#   Accuracy: 79.94%, Loss: 0.980624
#   Evaluation time: evaluation_time=0.5sec
#   Time: prune_time=8.7sec
#
# --------------------------------------------------------------------------------
# num_epoch=6
# -----------------------
# Pruner step 1 (of 3)
#     Calculated gradient in 0.02s
#     w_name='linear_relu_stack.linear1.weight' k_effective=512
#     _calc_grad_sample_block() took: 0.05s
#     _calc_hess_block() took: 0.05s
#     scaling=1.375e+07 cutoff=1.000e-12 Q_density=0.99849 Q_density_cutoff=0.49964
#     Solving with ConstrainedSASolver, problem_filename=PosixPath('.25435_250619_150954135372_d09a8568e0e64020844f337e769261e4.tmp')
#     n=1024 best_E=19722.987 elapsed_time=2.502
#     dL=0.000 dE=0.001 ridge_contribution=0.001 const=-0.000 best_E=0.001 dL_eval=-0.014 delta_w_squared=0.898
#     Pruner step took: 3.70s
# -----------------------
# Pruner step 2 (of 3)
#     Calculated gradient in 0.02s
#     w_name='linear_relu_stack.linear2.weight' k_effective=512
#     _calc_grad_sample_block() took: 0.04s
#     _calc_hess_block() took: 0.04s
#     scaling=1.425e+06 cutoff=1.000e-12 Q_density=0.25049 Q_density_cutoff=0.12929
#     Solving with ConstrainedSASolver, problem_filename=PosixPath('.25435_250619_150957801827_64533e2f2e5043bba1980b398bffb9c0.tmp')
#     n=1024 best_E=1321.978 elapsed_time=3.728
#     dL=0.005 dE=0.006 ridge_contribution=0.001 const=0.005 best_E=0.001 dL_eval=-0.018 delta_w_squared=1.464
#     Pruner step took: 4.53s
# -----------------------
# Pruner step 3 (of 3)
#     Calculated gradient in 0.00s
#     w_name='linear_relu_stack.linear3.weight' k_effective=512
#     _calc_grad_sample_block() took: 0.00s
#     _calc_hess_block() took: 0.00s
#     scaling=2.439e+05 cutoff=1.000e-12 Q_density=0.99997 Q_density_cutoff=0.52787
#     Solving with ConstrainedSASolver, problem_filename=PosixPath('.25435_250619_151002250333_7da9341897d642af89ec86c697323ca2.tmp')
#     n=611 best_E=74156.005 elapsed_time=0.353
#     dL=0.185 dE=0.186 ridge_contribution=0.000 const=-0.118 best_E=0.304 dL_eval=-0.003 delta_w_squared=0.209
#     Pruner step took: 0.78s
#
# Evaluating model after epoch 6:
#   Accuracy: 80.20%, Loss: 0.952469
#   Evaluation time: evaluation_time=0.5sec
#   Time: prune_time=9.1sec
#
# --------------------------------------------------------------------------------
# num_epoch=7
# -----------------------
# Pruner step 1 (of 3)
#     Calculated gradient in 0.00s
#     w_name='linear_relu_stack.linear3.weight' k_effective=512
#     _calc_grad_sample_block() took: 0.00s
#     _calc_hess_block() took: 0.00s
#     scaling=1.682e+05 cutoff=1.000e-12 Q_density=1.00000 Q_density_cutoff=0.53374
#     Solving with ConstrainedSASolver, problem_filename=PosixPath('.25435_250619_151003555429_29272fe00d5d4cf4b9f2a6a605b3c230.tmp')
#     n=665 best_E=52548.068 elapsed_time=0.519
#     dL=0.232 dE=0.232 ridge_contribution=0.000 const=-0.080 best_E=0.312 dL_eval=-0.004 delta_w_squared=0.313
#     Pruner step took: 1.02s
# -----------------------
# Pruner step 2 (of 3)
#     Calculated gradient in 0.02s
#     w_name='linear_relu_stack.linear1.weight' k_effective=512
#     _calc_grad_sample_block() took: 0.05s
#     _calc_hess_block() took: 0.06s
#     scaling=1.357e+07 cutoff=1.000e-12 Q_density=0.99495 Q_density_cutoff=0.49878
#     Solving with ConstrainedSASolver, problem_filename=PosixPath('.25435_250619_151004729702_86348b4f75394116a7f50189d261141f.tmp')
#     n=1024 best_E=20863.019 elapsed_time=2.259
#     dL=-0.007 dE=-0.006 ridge_contribution=0.001 const=-0.007 best_E=0.002 dL_eval=-0.020 delta_w_squared=0.868
#     Pruner step took: 3.47s
# -----------------------
# Pruner step 3 (of 3)
#     Calculated gradient in 0.02s
#     w_name='linear_relu_stack.linear2.weight' k_effective=512
#     _calc_grad_sample_block() took: 0.04s
#     _calc_hess_block() took: 0.04s
#     scaling=2.197e+06 cutoff=1.000e-12 Q_density=0.25049 Q_density_cutoff=0.13017
#     Solving with ConstrainedSASolver, problem_filename=PosixPath('.25435_250619_151008158082_674dc689925348e98b786fc0b9cf3873.tmp')
#     n=1024 best_E=2028.553 elapsed_time=3.552
#     dL=-0.015 dE=-0.013 ridge_contribution=0.001 const=-0.014 best_E=0.001 dL_eval=-0.019 delta_w_squared=1.454
#     Pruner step took: 4.30s
#
# Evaluating model after epoch 7:
#   Accuracy: 82.78%, Loss: 0.922624
#   Evaluation time: evaluation_time=0.5sec
#   Time: prune_time=8.8sec
#
# --------------------------------------------------------------------------------
# num_epoch=8
# -----------------------
# Pruner step 1 (of 3)
#     Calculated gradient in 0.00s
#     w_name='linear_relu_stack.linear3.weight' k_effective=512
#     _calc_grad_sample_block() took: 0.00s
#     _calc_hess_block() took: 0.00s
#     scaling=1.456e+05 cutoff=1.000e-12 Q_density=0.99977 Q_density_cutoff=0.53118
#     Solving with ConstrainedSASolver, problem_filename=PosixPath('.25435_250619_151012884395_ecd502e189364a8298ec1d4493e2f35b.tmp')
#     n=603 best_E=74919.703 elapsed_time=0.337
#     dL=0.300 dE=0.300 ridge_contribution=0.000 const=-0.214 best_E=0.515 dL_eval=-0.008 delta_w_squared=0.270
#     Pruner step took: 0.75s
# -----------------------
# Pruner step 2 (of 3)
#     Calculated gradient in 0.02s
#     w_name='linear_relu_stack.linear1.weight' k_effective=512
#     _calc_grad_sample_block() took: 0.06s
#     _calc_hess_block() took: 0.06s
#     scaling=1.644e+07 cutoff=1.000e-12 Q_density=0.99895 Q_density_cutoff=0.50142
#     Solving with ConstrainedSASolver, problem_filename=PosixPath('.25435_250619_151013792539_e385af7afd944b048c769a374b8b6ff9.tmp')
#     n=1024 best_E=25750.848 elapsed_time=2.278
#     dL=-0.007 dE=-0.007 ridge_contribution=0.001 const=-0.008 best_E=0.002 dL_eval=-0.020 delta_w_squared=0.863
#     Pruner step took: 3.50s
# -----------------------
# Pruner step 3 (of 3)
#     Calculated gradient in 0.01s
#     w_name='linear_relu_stack.linear2.weight' k_effective=512
#     _calc_grad_sample_block() took: 0.04s
#     _calc_hess_block() took: 0.04s
#     scaling=2.749e+06 cutoff=1.000e-12 Q_density=0.25049 Q_density_cutoff=0.12817
#     Solving with ConstrainedSASolver, problem_filename=PosixPath('.25435_250619_151017241120_d713023209314a37a848a7e67c9380ac.tmp')
#     n=1024 best_E=2535.479 elapsed_time=3.512
#     dL=-0.010 dE=-0.009 ridge_contribution=0.001 const=-0.010 best_E=0.001 dL_eval=-0.013 delta_w_squared=1.398
#     Pruner step took: 4.25s
#
# Evaluating model after epoch 8:
#   Accuracy: 82.49%, Loss: 0.897431
#   Evaluation time: evaluation_time=0.5sec
#   Time: prune_time=8.5sec
#
# --------------------------------------------------------------------------------
# num_epoch=9
# -----------------------
# Pruner step 1 (of 3)
#     Calculated gradient in 0.01s
#     w_name='linear_relu_stack.linear2.weight' k_effective=512
#     _calc_grad_sample_block() took: 0.04s
#     _calc_hess_block() took: 0.04s
#     scaling=2.689e+06 cutoff=1.000e-12 Q_density=0.25049 Q_density_cutoff=0.12796
#     Solving with ConstrainedSASolver, problem_filename=PosixPath('.25435_250619_151022009901_f3dba1cf37004b708a18ecaec6be2100.tmp')
#     n=1024 best_E=2435.094 elapsed_time=3.810
#     dL=-0.008 dE=-0.007 ridge_contribution=0.001 const=-0.008 best_E=0.001 dL_eval=-0.015 delta_w_squared=1.382
#     Pruner step took: 4.56s
# -----------------------
# Pruner step 2 (of 3)
#     Calculated gradient in 0.02s
#     w_name='linear_relu_stack.linear1.weight' k_effective=512
#     _calc_grad_sample_block() took: 0.05s
#     _calc_hess_block() took: 0.05s
#     scaling=1.900e+07 cutoff=1.000e-12 Q_density=0.99933 Q_density_cutoff=0.50009
#     Solving with ConstrainedSASolver, problem_filename=PosixPath('.25435_250619_151026633034_902fd9fdc9ed4f65a6707cd995b5520a.tmp')
#     n=1024 best_E=27043.815 elapsed_time=2.249
#     dL=-0.006 dE=-0.005 ridge_contribution=0.001 const=-0.006 best_E=0.001 dL_eval=-0.016 delta_w_squared=0.800
#     Pruner step took: 3.47s
# -----------------------
# Pruner step 3 (of 3)
#     Calculated gradient in 0.00s
#     w_name='linear_relu_stack.linear3.weight' k_effective=512
#     _calc_grad_sample_block() took: 0.00s
#     _calc_hess_block() took: 0.00s
#     scaling=1.865e+05 cutoff=1.000e-12 Q_density=0.99999 Q_density_cutoff=0.52618
#     Solving with ConstrainedSASolver, problem_filename=PosixPath('.25435_250619_151029968287_eb8a985e80794cd494fb905344b0d22f.tmp')
#     n=612 best_E=69360.508 elapsed_time=0.340
#     dL=0.308 dE=0.309 ridge_contribution=0.000 const=-0.063 best_E=0.372 dL_eval=0.000 delta_w_squared=0.248
#     Pruner step took: 0.77s
#
# Evaluating model after epoch 9:
#   Accuracy: 81.52%, Loss: 0.884505
#   Evaluation time: evaluation_time=0.6sec
#   Time: prune_time=8.8sec
#
# --------------------------------------------------------------------------------
# num_epoch=10
# -----------------------
# Pruner step 1 (of 3)
#     Calculated gradient in 0.02s
#     w_name='linear_relu_stack.linear1.weight' k_effective=512
#     _calc_grad_sample_block() took: 0.05s
#     _calc_hess_block() took: 0.06s
#     scaling=1.690e+07 cutoff=1.000e-12 Q_density=0.99947 Q_density_cutoff=0.49925
#     Solving with ConstrainedSASolver, problem_filename=PosixPath('.25435_250619_151031491456_b7b7c4cd84c14e53becd06958f946c53.tmp')
#     n=1024 best_E=21813.284 elapsed_time=2.412
#     dL=-0.001 dE=-0.000 ridge_contribution=0.001 const=-0.002 best_E=0.001 dL_eval=-0.013 delta_w_squared=0.839
#     Pruner step took: 3.62s
# -----------------------
# Pruner step 2 (of 3)
#     Calculated gradient in 0.00s
#     w_name='linear_relu_stack.linear3.weight' k_effective=512
#     _calc_grad_sample_block() took: 0.00s
#     _calc_hess_block() took: 0.00s
#     scaling=1.607e+05 cutoff=1.000e-12 Q_density=0.99971 Q_density_cutoff=0.53543
#     Solving with ConstrainedSASolver, problem_filename=PosixPath('.25435_250619_151034982299_70e4adb94d0649bdb2b1dad9f02c9b3f.tmp')
#     n=657 best_E=49550.721 elapsed_time=0.461
#     dL=0.173 dE=0.174 ridge_contribution=0.000 const=-0.135 best_E=0.308 dL_eval=-0.007 delta_w_squared=0.321
#     Pruner step took: 0.95s
# -----------------------
# Pruner step 3 (of 3)
#     Calculated gradient in 0.01s
#     w_name='linear_relu_stack.linear2.weight' k_effective=512
#     _calc_grad_sample_block() took: 0.04s
#     _calc_hess_block() took: 0.04s
#     scaling=2.359e+06 cutoff=1.000e-12 Q_density=0.25049 Q_density_cutoff=0.12645
#     Solving with ConstrainedSASolver, problem_filename=PosixPath('.25435_250619_151036032141_e9218a989fce4b568f9a06176cbb63f2.tmp')
#     n=1024 best_E=2188.690 elapsed_time=3.605
#     dL=-0.011 dE=-0.009 ridge_contribution=0.001 const=-0.010 best_E=0.001 dL_eval=-0.013 delta_w_squared=1.416
#     Pruner step took: 4.36s
#
# Evaluating model after epoch 10:
#   Accuracy: 82.09%, Loss: 0.864713
#   Evaluation time: evaluation_time=0.5sec
#   Time: prune_time=9.0sec
#
# Experiment took: 1.60min

# %% [markdown]
# ## Plot the results

# %%
# Plot the evolution of the validation accuracy across epochs
plt.figure()
plt.xlabel("Epoch")
plt.ylabel("Validation accuracy [%]")
plt.axhline(y=valid_accuracies[0], linestyle="--", label=f"{init_method}", color="b")
plt.axhline(y=unpruned_valid_accuracy, linestyle="--", label=f"No pruning", color="k")
plt.plot(valid_accuracies, label="iCBS (ours)", linestyle="--", color="r")
plt.legend()

# Plot the evolution of the validation accuracy across epochs
plt.figure()
plt.xlabel("Epoch")
plt.ylabel("Validation loss")
plt.axhline(y=valid_losses[0], linestyle="--", label=f"{init_method}", color="b")
plt.axhline(y=unpruned_valid_loss, linestyle="--", label=f"No pruning", color="k")
plt.plot(valid_losses, label="iCBS (ours)", linestyle="--", color="r")
plt.legend();
